# %% [markdown]
# # Removing Trends - Lab
#
# ## Introduction
#
# In this lab, you'll practice your detrending skills!
#
# ## Objectives
#
# You will be able to:
# * Learn how to remove trends and seasonality
# * Use a log transformation to minimize non-stationarity
# * Use rolling means to reduce non-stationarity
# * Use differencing to reduce non-stationarity

# %% [markdown]
# ## Detrending the Airpassenger data

# %%
# Import necessary libraries
import pandas as pd
from pandas import Series
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline


# Import passengers.csv and set it as a time-series object. Plot the TS
passengers = pd.read_csv("passengers.csv")
passengers.Month = pd.to_datetime(passengers.Month)
ts = passengers.set_index("Month")
ts.head()
ts.plot(figsize = (12,6), color = "blue")


# data = pd.read_csv('passengers.csv')
# ts = data.set_index('Month')
# ts.index = pd.to_datetime(ts.index)
# ts.plot(figsize=(12,6), color="blue");


# can convert to datetime object before or after you make it the index

# %% [markdown]
# ## Create a stationarity check
#
# At this stage, we can use the code from previous labs to create a function `stationarity_check(ts)` that takes in a time series object and performs stationarity checks including rolling statistics and the Dickey Fuller test.
#
# We want the output of the function to:
# - Plot the original time series along with the rolling mean and rolling standard deviation in one plot
# - Output the results of the Dickey-Fuller test

# %%
# Create a function to check for the stationarity of a given timeseries using rolling stats and DF test
# Collect and package the code from previous lab

from statsmodels.tsa.stattools import adfuller

# %%
type(ts)
ts.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
def stationary_check(ts):
    """
    plots the time series, rolling means and rolling standard deviations
    
    
    
    """

    rolling_mean = ts.rolling(window = 8, center = False).mean()
    rolling_std = ts.rolling(window = 8, center = False).std()
    
    # dickey fuller test: tests the null hypothesis that a unit root
    # is present in an autoregressive mode 
    
    # unit root test tests whether a time series variable is non-stationary and possesses a unit root.
    
    dftest = adfuller(ts["#Passengers"])
    
    
    fig = plt.figure(figsize=(12,6))
    orig = plt.plot(ts, color='blue',label='Original')
    mean = plt.plot(rolling_mean, color='red', label='Rolling Mean')
    std = plt.plot(rolling_std, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
 


    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
stationary_check(ts)
# Out:
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# Use your newly created function on the airpassenger data set.

# %%
# Code here

# %% [markdown]
# ## Perform a log() and sqrt() transform

# %%
# Log transform timeseries and compare with original to check the effect

ts_log = np.log(ts)
ts_sqrt = np.sqrt(ts)

plt.title("ts")
plt.plot(ts)
plt.figure()
plt.title("ts log")
plt.plot(ts_log);

plt.figure()
plt.title("ts square root")
plt.plot(ts_sqrt);

# %% [markdown]
# moving forward, let's keep working with the log transformed data before subtracting rolling mean, differencing, etc.

# %% [markdown]
# ## Subtracting the rolling mean

# %% [markdown]
# Create a rolling mean using your log transformed time series, with a time window of 7. Plot the log-transformed time series and the rolling mean together.

# %%
# your code here


rolling_mean_log =  ts_log.rolling(window = 7).mean()
# rolling_std_log =   ts_log.rolling(window = 7).std()


plt.plot(ts_log, label = "ts log")
plt.plot(rolling_mean_log, label = "rolling mean of ts log")
plt.legend()

# %%
# each new value is an average of the last 7 values 
rolling_mean_log.iloc[10:20]
# Out:
#             #Passengers
# Month
# 1949-11-01     4.861666
# 1949-12-01     4.858079
# 1950-01-01     4.835173
# 1950-02-01     4.812183
# 1950-03-01     4.805261
# 1950-04-01     4.804207
# 1950-05-01     4.811234
# 1950-06-01     4.862599
# 1950-07-01     4.914758
# 1950-08-01     4.970596

# %% [markdown]
# Now, subtract the rolling mean from the time series, look at the 10 first elements of the result and plot the result.

# %%
# Subtract the moving average from the original data and check head for Nans

log_minus_rolmean = ts_log - rolling_mean_log

# %%
# Drop the NaN values from timeseries calculated above
log_minus_rolmean.dropna(inplace = True)

log_minus_rolmean.isnull().sum()
# Out:
# #Passengers    0
# dtype: int64

# %%
# Plot the result
plt.plot(log_minus_rolmean)

# %%
stationary_check(log_minus_rolmean)
# Out:
# Test Statistic                  -2.348027
# p-value                          0.156946
# #Lags Used                      14.000000
# Number of Observations Used    123.000000
# Critical Value (1%)             -3.484667
# Critical Value (5%)             -2.885340
# Critical Value (10%)            -2.579463
# dtype: float64

# %% [markdown]
# Finally, use your function `check_stationarity` to see if this series is considered stationary!

# %%
# Your code here

# %% [markdown]
# ### Based on the visuals and on the Dickey-Fuller test, what do you conclude?

# %% [markdown]
# time series is not stationary, p value of .015 is greater than 0.05

# %% [markdown]
# ## Subtracting the weighted rolling mean

# %% [markdown]
# Repeat all the above for the *weighter* rolling mean. Start from the log-transformed data again. Compare the Dickey-Fuller Test results. What do you conclude?

# %%
# Use Pandas ewma() to calculate Weighted Moving Average of ts_log

#weights the more recent values higher

ewm_rolmean = ts_log.ewm(halflife=4).mean()
# Plot the original data with exp weighted average

plt.plot(ewm_rolmean, label = "weighted moving average");
plt.plot(rolling_mean_log, label ="rolling mean");
#plt.plot(ts_log, label = "ts log")

plt.legend()

# weighted average is more linear, peaks are muted

# %%
# Subtract the moving average from the original data and plot

ts_log_minus_ewm = ts_log - ewm_rolmean
ts_log_minus_ewm.head()
# Out:
#             #Passengers
# Month
# 1949-01-01     0.000000
# 1949-02-01     0.023838
# 1949-03-01     0.082598
# 1949-04-01     0.040640
# 1949-05-01    -0.016963

# %%
plt.plot(ts_log_minus_ewm)

# %%
# do a stationarity check
stationary_check(ts_log_minus_ewm)
# Out:
# Test Statistic                  -3.297250
# p-value                          0.015002
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# ### Based on the visuals and on the Dickey-Fuller test, what do you conclude?

# %% [markdown]
# p-value is less than 0.05, indicating that the data is stationary, though still seasonal

# %%
# what did we do so far
all_ts = ts.rename(columns = {"#Passengers": "Original"})
all_ts["Log Transform"] = ts_log["#Passengers"]
all_ts["Sqrt Transform"] = ts_sqrt["#Passengers"]
# all_ts["Log Transform"] =

# %% [markdown]
# ## Differencing

# %% [markdown]
# Using exponentially weighted moving averages, we seem to have removed the upward trend, but not the seasonality issue. Now use differencing to remove seasonality. Make sure you use the right amount of `periods`. Start from the log-transformed, exponentially weighted rolling mean-subtracted series.
#
# After you differenced the series, run the `stationarity check` again.

# %%
# difference your data and look at the head

data_diff = ts_log_minus_ewm.diff(periods = 12)
data_diff.iloc[10:20]


"""
First discrete difference of element.

Calculates the difference of a DataFrame element compared with another
element in the DataFrame (default is the element in the same column
of the previous row).

periods : int, default 1
    Periods to shift for calculating difference, accepts negative
    values.
    
    
we set periods equal to 12 to subtract the value from the
year before 

we subtract the log



"""
# Out:
#             #Passengers
# Month
# 1949-11-01          NaN
# 1949-12-01          NaN
# 1950-01-01    -0.063907
# 1950-02-01    -0.001185
# 1950-03-01     0.029307
# 1950-04-01     0.016168
# 1950-05-01     0.000194
# 1950-06-01     0.062669
# 1950-07-01     0.095524
# 1950-08-01     0.085827

# %%
# plot your differenced time series


fig = plt.figure(figsize = (11,7))
plt.plot(data_diff)

# %%
# drop nas
data_diff.dropna(inplace = True)

# %%
# perform the stationarity check
stationary_check(data_diff)
# Out:
# Test Statistic                  -3.601666
# p-value                          0.005729
# #Lags Used                      12.000000
# Number of Observations Used    119.000000
# Critical Value (1%)             -3.486535
# Critical Value (5%)             -2.886151
# Critical Value (10%)            -2.579896
# dtype: float64

# %% [markdown]
# ### Your conclusion

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to make time series stationary through using log transforms, rolling means and differencing.

# %%
data_diff = ts.diff(periods = 12)
data_diff.iloc[10:20]
